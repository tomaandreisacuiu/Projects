# %% [markdown]
# # Programming Lesson and Exercises - EDA<span class="tocSkip"></span>
#
# The goal of these programming lesson and exercises is to teach you _Exploratory Data Analytics_.

# %% [markdown]
# This notebook has the following structure:
#
# - The first part introduces the concepts for this week. The theory is interleaved with small exercises, which have the goal of letting you practice the concepts that were just intruduced.
# - At the end there are one or more larger exercises, which have the goal to test what you have learned earlier. These will be more difficult and will require more independent work than the exercises in the first part.
#
# All exercises can be solved with the concepts that were introduced earlier. Since there are often more than one correct way to solve a programming problem, we try to accept various correct anwers. However, many of the automatic tests in Momotor (see _How to submit your work_ below) assume that your answers are constructed using the concepts introduced in these notebooks. If you look for answers on the Internet (e.g. if you import other libraries) you run the risk that your answers will be rejected.
#
# Some of the small exercises can be solved by copy-pasting code from the examples. However, it is up to you to try to solve the exercises yourself, which will help you learn, before copy-pasting the answers. The ease of looking up answers is meant to provide guidance when you get stuck, especially for those of you who are new to programming.
#
# For your convenience, in the `support` directory you will find an HTML version of this notebook and a summary of the Python methods introduced in this notebook.
#
#
#
# # Introduction to this template notebook
#
# * This is a **personal** notebook.
# * Make sure you work in a **copy** of `...-template.ipynb`, **renamed** to `...-yourIDnr.ipynb`, where `yourIDnr` is your TU/e identification number.
# * Keep the copy in the same folder, so that the provided data sets can be loaded.
#
# You are expected to work with Python code in this notebook. The locations where you should write your solutions can be recognized by **marker lines**, which look like this:
#
# >`#//`
# >    `BEGIN_TODO [Label]` `Description` `(n points)`
# >
# >`#//`
# >    `END_TODO [Label]`
#
# <div class="alert alert-warning" role="alert">
# <ul>
#     <li>Do NOT modify or delete these marker lines.  Keep them as they are.</li>
#     <li>NEVER write code <i>outside</i> the marked blocks. Such code cannot be evaluated.</li>
# </ul>
# </div>
#
# Proceed in this notebook as follows:
# * **Read** the text.
# * **Fill in** your solutions between `BEGIN_TODO` and `END_TODO` marker lines.
# * **Run** _all_ code cells (also the ones _without_ your code),
#     _in linear order_ from the first code cell.
#
# <div class="alert alert-danger" role="danger">
# <h3>Integrity</h3>
# <ul>
#     <li>In this course you must act according to the rules of the TU/e code of scientific conduct.</li>
#     <li>All the exercises and the graded assignments are to be executed individually and independently.</li>
#     <li>You must not copy from the Internet, your friends, books... If you represent other people's work as your own, then that constitutes fraud and will be reported to the Examination Committee.</li>
#     <li>Making your work available to others (complicity) also constitutes fraud.</li>
# </ul>
# </div>
#
# ## Personalize your notebook
#
# 1. Copy the following three lines of code:
#
#   ```python
#   AUTHOR_NAME = 'Your Full Name'
#   AUTHOR_ID_NR = '1234567'
#   AUTHOR_DATE = 'YYYY-MM-DD'
#   ```
#
# 1. Paste them between the marker lines in the next code cell.
# 1. Fill in your _full name, identification number,_ and the current _date_ (i.e. when you first modified this notebook, e.g. `'2020-02-26'`) as strings between quotes.
# 1. Run the code cell by putting the cursor there and typing **Control-Enter**.

# %%
#// BEGIN_TODO [Author] Name, Id.nr., Date, as strings (1 point)

AUTHOR_NAME = 'Toma Andrei Sacuiu'
AUTHOR_ID_NR = '1681591'
AUTHOR_DATE = '2022-02-15'

#// END_TODO [Author]

AUTHOR_NAME, AUTHOR_ID_NR, AUTHOR_DATE
# Out:
# ('Toma Andrei Sacuiu', '1681591', '2022-02-15')

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Learning-Objectives" data-toc-modified-id="Learning-Objectives-1">Learning Objectives</a></span></li><li><span><a href="#Introduction" data-toc-modified-id="Introduction-2">Introduction</a></span><ul class="toc-item"><li><span><a href="#Other-learning-resources-for-Pandas" data-toc-modified-id="Other-learning-resources-for-Pandas-2.1">Other learning resources for Pandas</a></span></li><li><span><a href="#Importing-the-library" data-toc-modified-id="Importing-the-library-2.2">Importing the library</a></span></li><li><span><a href="#1.-Data-frames" data-toc-modified-id="1.-Data-frames-2.3"><span class="section">1.</span> Data frames</a></span><ul class="toc-item"><li><span><a href="#Information-about-a-DataFrame" data-toc-modified-id="Information-about-a-DataFrame-2.3.1">Information about a <code>DataFrame</code></a></span></li><li><span><a href="#Exercise-1.a" data-toc-modified-id="Exercise-1.a-2.3.2">Exercise <span class="exercise">1.a</span></a></span></li><li><span><a href="#Exercise-1.b" data-toc-modified-id="Exercise-1.b-2.3.3">Exercise <span class="exercise">1.b</span></a></span></li></ul></li><li><span><a href="#2.-Index-and-Series-objects" data-toc-modified-id="2.-Index-and-Series-objects-2.4"><span class="section">2.</span> <code>Index</code> and <code>Series</code> objects</a></span><ul class="toc-item"><li><span><a href="#Exercise-2.a" data-toc-modified-id="Exercise-2.a-2.4.1">Exercise <span class="exercise">2.a</span></a></span></li></ul></li><li><span><a href="#Error-handling" data-toc-modified-id="Error-handling-2.5">Error handling</a></span></li><li><span><a href="#3.-Getting-data-from-a-DataFrame" data-toc-modified-id="3.-Getting-data-from-a-DataFrame-2.6"><span class="section">3.</span> Getting data from a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Exercise-3.a" data-toc-modified-id="Exercise-3.a-2.6.1">Exercise <span class="exercise">3.a</span></a></span></li><li><span><a href="#Exercise-3.b" data-toc-modified-id="Exercise-3.b-2.6.2">Exercise <span class="exercise">3.b</span></a></span></li><li><span><a href="#Exercise-3.c" data-toc-modified-id="Exercise-3.c-2.6.3">Exercise <span class="exercise">3.c</span></a></span></li></ul></li><li><span><a href="#4.-Modifying-a-DataFrame" data-toc-modified-id="4.-Modifying-a-DataFrame-2.7"><span class="section" id="section_copy">4.</span> Modifying a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Changing-a-value-in-a-DataFrame" data-toc-modified-id="Changing-a-value-in-a-DataFrame-2.7.1">Changing a value in a <code>DataFrame</code></a></span></li><li><span><a href="#Changing-values-in-a-slice-from-a-DataFrame" data-toc-modified-id="Changing-values-in-a-slice-from-a-DataFrame-2.7.2">Changing values in a slice from a <code>DataFrame</code></a></span></li><li><span><a href="#Exercise-4.a" data-toc-modified-id="Exercise-4.a-2.7.3">Exercise <span class="exercise">4.a</span></a></span></li><li><span><a href="#Exercise-4.b" data-toc-modified-id="Exercise-4.b-2.7.4">Exercise <span class="exercise">4.b</span></a></span></li></ul></li><li><span><a href="#5.-Setting-the-index-of-a-DataFrame" data-toc-modified-id="5.-Setting-the-index-of-a-DataFrame-2.8"><span class="section">5.</span> Setting the index of a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Exercise-5.a" data-toc-modified-id="Exercise-5.a-2.8.1">Exercise <span class="exercise">5.a</span></a></span></li><li><span><a href="#Exercise-5.b" data-toc-modified-id="Exercise-5.b-2.8.2">Exercise <span class="exercise">5.b</span></a></span></li></ul></li><li><span><a href="#6.-Reading-data-from-a-file-into-a-DataFrame" data-toc-modified-id="6.-Reading-data-from-a-file-into-a-DataFrame-2.9"><span class="section">6.</span> Reading data from a file into a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Exercise-6.a" data-toc-modified-id="Exercise-6.a-2.9.1">Exercise <span class="exercise">6.a</span></a></span></li><li><span><a href="#Exercise-6.b" data-toc-modified-id="Exercise-6.b-2.9.2">Exercise <span class="exercise">6.b</span></a></span></li></ul></li><li><span><a href="#7.-Summary-statistics" data-toc-modified-id="7.-Summary-statistics-2.10"><span class="section">7.</span> Summary statistics</a></span><ul class="toc-item"><li><span><a href="#Separate-statistics" data-toc-modified-id="Separate-statistics-2.10.1">Separate statistics</a></span></li><li><span><a href="#Exercise-7.a" data-toc-modified-id="Exercise-7.a-2.10.2">Exercise <span class="exercise">7.a</span></a></span></li><li><span><a href="#Exercise-7.b" data-toc-modified-id="Exercise-7.b-2.10.3">Exercise <span class="exercise">7.b</span></a></span></li></ul></li><li><span><a href="#8.-Sorting-a-DataFrame" data-toc-modified-id="8.-Sorting-a-DataFrame-2.11"><span class="section">8.</span> Sorting a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Exercise-8.a" data-toc-modified-id="Exercise-8.a-2.11.1">Exercise <span class="exercise">8.a</span></a></span></li></ul></li><li><span><a href="#9.-Computing-values-from-a-DataFrame" data-toc-modified-id="9.-Computing-values-from-a-DataFrame-2.12"><span class="section">9.</span> Computing values from a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Adding-a-new-column-to-a-DataFrame" data-toc-modified-id="Adding-a-new-column-to-a-DataFrame-2.12.1">Adding a new column to a <code>DataFrame</code></a></span></li><li><span><a href="#Exercise-9.a" data-toc-modified-id="Exercise-9.a-2.12.2">Exercise <span class="exercise">9.a</span></a></span></li></ul></li><li><span><a href="#10.-Selecting-rows-by-boolean-masks" data-toc-modified-id="10.-Selecting-rows-by-boolean-masks-2.13"><span class="section">10.</span> Selecting rows by boolean masks</a></span><ul class="toc-item"><li><span><a href="#Boolean-mask-for-missing-values" data-toc-modified-id="Boolean-mask-for-missing-values-2.13.1">Boolean mask for missing values</a></span></li><li><span><a href="#Combining-boolean-masks" data-toc-modified-id="Combining-boolean-masks-2.13.2">Combining boolean masks</a></span></li><li><span><a href="#Exercise-10.a" data-toc-modified-id="Exercise-10.a-2.13.3">Exercise <span class="exercise">10.a</span></a></span></li><li><span><a href="#Exercise-10.b" data-toc-modified-id="Exercise-10.b-2.13.4">Exercise <span class="exercise">10.b</span></a></span></li><li><span><a href="#Exercise-10.c" data-toc-modified-id="Exercise-10.c-2.13.5">Exercise <span class="exercise">10.c</span></a></span></li><li><span><a href="#Exercise-10.d" data-toc-modified-id="Exercise-10.d-2.13.6">Exercise <span class="exercise">10.d</span></a></span></li><li><span><a href="#Exercise-10.e" data-toc-modified-id="Exercise-10.e-2.13.7">Exercise <span class="exercise">10.e</span></a></span></li><li><span><a href="#Exercise-10.f" data-toc-modified-id="Exercise-10.f-2.13.8">Exercise <span class="exercise">10.f</span></a></span></li></ul></li><li><span><a href="#11.-Grouping-rows-in-a-DataFrame" data-toc-modified-id="11.-Grouping-rows-in-a-DataFrame-2.14"><span class="section">11.</span> Grouping rows in a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Exercise-11.a" data-toc-modified-id="Exercise-11.a-2.14.1">Exercise <span class="exercise">11.a</span></a></span></li><li><span><a href="#Exercise-11.b" data-toc-modified-id="Exercise-11.b-2.14.2">Exercise <span class="exercise">11.b</span></a></span></li><li><span><a href="#Exercise-11.c" data-toc-modified-id="Exercise-11.c-2.14.3">Exercise <span class="exercise">11.c</span></a></span></li></ul></li><li><span><a href="#12.-Deleting-rows-or-columns-from-a-DataFrame" data-toc-modified-id="12.-Deleting-rows-or-columns-from-a-DataFrame-2.15"><span class="section">12.</span> Deleting rows or columns from a <code>DataFrame</code></a></span></li><li><span><a href="#13.-Persisting-the-modifications" data-toc-modified-id="13.-Persisting-the-modifications-2.16"><span class="section">13.</span> Persisting the modifications</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#The-inplace-argument" data-toc-modified-id="The-inplace-argument-2.16.0.1">The <code>inplace</code> argument</a></span></li></ul></li></ul></li><li><span><a href="#14.-Plotting-a-DataFrame" data-toc-modified-id="14.-Plotting-a-DataFrame-2.17"><span class="section">14.</span> Plotting a <code>DataFrame</code></a></span><ul class="toc-item"><li><span><a href="#Line-plot" data-toc-modified-id="Line-plot-2.17.1">Line plot</a></span></li><li><span><a href="#Area-plot" data-toc-modified-id="Area-plot-2.17.2">Area plot</a></span></li><li><span><a href="#Dot-plot" data-toc-modified-id="Dot-plot-2.17.3">Dot plot</a></span></li><li><span><a href="#Histogram" data-toc-modified-id="Histogram-2.17.4">Histogram</a></span></li><li><span><a href="#Density-plot" data-toc-modified-id="Density-plot-2.17.5">Density plot</a></span></li><li><span><a href="#Box-plot" data-toc-modified-id="Box-plot-2.17.6">Box plot</a></span></li><li><span><a href="#Bar-plot" data-toc-modified-id="Bar-plot-2.17.7">Bar plot</a></span></li><li><span><a href="#Scatter-plot" data-toc-modified-id="Scatter-plot-2.17.8">Scatter plot</a></span></li><li><span><a href="#Exercise-14.a" data-toc-modified-id="Exercise-14.a-2.17.9">Exercise <span class="exercise">14.a</span></a></span></li><li><span><a href="#Exercise-14.b" data-toc-modified-id="Exercise-14.b-2.17.10">Exercise <span class="exercise">14.b</span></a></span></li><li><span><a href="#Exercise-14.c" data-toc-modified-id="Exercise-14.c-2.17.11">Exercise <span class="exercise">14.c</span></a></span></li><li><span><a href="#Exercise-14.d" data-toc-modified-id="Exercise-14.d-2.17.12">Exercise <span class="exercise">14.d</span></a></span></li><li><span><a href="#Exercise-14.e" data-toc-modified-id="Exercise-14.e-2.17.13">Exercise <span class="exercise">14.e</span></a></span></li><li><span><a href="#Exercise-14.f" data-toc-modified-id="Exercise-14.f-2.17.14">Exercise <span class="exercise">14.f</span></a></span></li><li><span><a href="#Exercise-14.g" data-toc-modified-id="Exercise-14.g-2.17.15">Exercise <span class="exercise">14.g</span></a></span></li><li><span><a href="#Exercise-14.h" data-toc-modified-id="Exercise-14.h-2.17.16">Exercise <span class="exercise">14.h</span></a></span></li><li><span><a href="#Exercise-14.i" data-toc-modified-id="Exercise-14.i-2.17.17">Exercise <span class="exercise">14.i</span></a></span></li></ul></li></ul></li><li><span><a href="#15.-Exercise:-speed-of-light" data-toc-modified-id="15.-Exercise:-speed-of-light-3"><span class="section">15.</span> Exercise: speed of light</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Exercise-15.a:-Load-the-data-set" data-toc-modified-id="Exercise-15.a:-Load-the-data-set-3.0.1">Exercise <span class="exercise">15.a</span>: Load the data set</a></span></li><li><span><a href="#Exercise-15.b:-Summary-statistics-of-raw-values" data-toc-modified-id="Exercise-15.b:-Summary-statistics-of-raw-values-3.0.2">Exercise <span class="exercise">15.b</span>: Summary statistics of raw values</a></span></li><li><span><a href="#Exercise-15.c:-Observation" data-toc-modified-id="Exercise-15.c:-Observation-3.0.3">Exercise <span class="exercise">15.c</span>: Observation</a></span></li><li><span><a href="#Exercise-15.d:-Add-column-with-the-decoded-speed" data-toc-modified-id="Exercise-15.d:-Add-column-with-the-decoded-speed-3.0.4">Exercise <span class="exercise">15.d</span>: Add column with the decoded speed</a></span></li><li><span><a href="#Exercise-15.e:-Summary-statistics-of-the-decoded-speed" data-toc-modified-id="Exercise-15.e:-Summary-statistics-of-the-decoded-speed-3.0.5">Exercise <span class="exercise">15.e</span>: Summary statistics of the decoded speed</a></span></li><li><span><a href="#Exercise-15.f:-Make-a-dot-plot" data-toc-modified-id="Exercise-15.f:-Make-a-dot-plot-3.0.6">Exercise <span class="exercise">15.f</span>: Make a dot plot</a></span></li><li><span><a href="#Exercise-15.g:-Remove-suspicious-rows" data-toc-modified-id="Exercise-15.g:-Remove-suspicious-rows-3.0.7">Exercise <span class="exercise">15.g</span>: Remove suspicious rows</a></span></li><li><span><a href="#Exercise-15.h:-Find-the-definition-of-the-speed-of-light" data-toc-modified-id="Exercise-15.h:-Find-the-definition-of-the-speed-of-light-3.0.8">Exercise <span class="exercise">15.h</span>: Find the definition of the speed of light</a></span></li><li><span><a href="#Exercise-15.i:-Compare-to-current-estimate" data-toc-modified-id="Exercise-15.i:-Compare-to-current-estimate-3.0.9">Exercise <span class="exercise">15.i</span>: Compare to current estimate</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Learning Objectives
#
# After this section, you should
#
# * Be able to work with Pandas `DataFrame` and `Series` objects;
#     in particular,
#
#     * to create,
#     * to inspect and extract parts from,
#     * to modify,
#     * to compute summary statistics for, and
#     * to visualize
#
#   `DataFrame` objects.

# %% [markdown]
# # Introduction
#
# Most of the programming for Data Analytics will involve
# Python libraries that provide solutions for specific data analysis tasks.
#
# In this section,
# we introduce you to the **Pandas** library.
# The name _Pandas_ is a contraction of _Panel Data_ ,
# which you can think of as tabular data, like a spreadsheet,
# with multiple (labeled) rows and columns.
#
# The Pandas library is automatically installed when _Anaconda_ is installed.

# %% [markdown]
# ## Other learning resources for Pandas
#
# This section cannot and will not cover all details.
# We have selected a small number of key features
# to achieve maximal effect.
#
# Sometimes you may want to consult other information sources:
#
# * `tool-summary*.ipynb`
# * The _Python Data Science Handbook_ by Jake VanderPlas,
#   the chapter [_Data Manipulation with Pandas_](https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/03.00-Introduction-to-Pandas.ipynb)
#   It provides a more comprehensive introduction, and further background information.
#   This book is also available as [ebook in the TU/e library](https://tue.on.worldcat.org/oclc/964358680).
# * The official [Pandas documentation](http://pandas.pydata.org/).
#   The Jupyter Notebook Help menu contains a menu item that leads there.
# * **Code completion** and **built-in** help in code cells,
#   using the **TAB** key and **Shift-TAB-TAB**.
# * Web search; but be warned that older solutions may no longer be valid or the most appropriate.

# %% [markdown]
# Some exercises contain hints. Execute the following code cell to hide them by default and reveal the hints while pressing with the mouse on the "Hint" label. This will give you a chance to think for yourself before seeing a hint.

# %%
from IPython.display import HTML
HTML("<style>.h,.c{display:none}.t{color:#296eaa}.t:active+.h{display:block;}</style>")
# Out:
# <style>.h,.c{display:none}.t{color:#296eaa}.t:active+.h{display:block;}</style>

# %% [markdown]
# ## Importing the library
#
# In order to use facilities from Pandas, you first need to import the Pandas library.
# It is useful to import NumPy as well,
# even though we will not make (much) use of it,
# since Pandas is built on top of NumPy.
#
# The next code cell shows the common way to do these imports,
# introducing the abbreviations `np` for NumPy and `pd` for Pandas.
# Execute this code cell (it will not result in any output).

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# When you type an _identifier_ in a code cell, such as `pd`, followed by **Shift-TAB-TAB**,
# you get a floating window with the **built-in documentation** for that identifier:
#
# ![Shift-Tab-Tab.png](attachment:Shift-Tab-Tab.png)
#
# Try it with `pd`:

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %% [markdown]
# Alternatively, you can show the built-in documentation by appending a `?` at the end:

# %%
pd?
# Out:
#   File "<ipython-input-5-4d1f54e2bebd>", line 1
#     pd?
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# When you type *part of an identifier*,
# followed by **TAB**, an attempt is made at **code completion**.
# When there are multiple possibilities to complete the identifier,
# a pop-up menu with all options is shown:
#
# ![Code-Completion.png](attachment:Code-Completion.png)
#
# You can either
# * continue typing more characters of the identifier,
#     in which case the shown list will become shorter, or
# * you can select a particular item by
#     * clicking it with the mouse pointer, or
#     * moving the selection with the _arrow keys_ and hitting *Enter*.
#
# Try it: starting with `pd.D` hit TAB to complete this to `pd.DataFrame`.
# Next, do Shift-TAB-TAB to get its built-in documentation.

# %%
pd.DataFrame

# %% [markdown]
# ## <span class="section">1.</span> Data frames
#
# The most important data type of the Pandas library is **`pd.DataFrame`**.
# It is a _composite_ data type, whose values are called **data frames**.
#
# A data frame is a two-dimensional arrangement of data values. It can be helpful to think of it as a table with rows and columns.
# The data itself is typically of a primitive data type (`int`, `float`, `bool`, `str`,
# but also some variants of these as offered by the NumPy library;
# details are not relevant at this point).
#
# Here is an example in which we create a data frame from scratch; we name it `df`.
# It has
#
# * four rows indexed from 0 through 3, and
# * three columns labeled `'A'`, `'B'`, and `'C'`.

# %%
df_example = pd.DataFrame({'A': [1, 2, 3, 4], 'B': ['one', 'two', 'three', 'four'], 'C': [False, True, False, True]})
df_example

# %% [markdown]
# The following diagram illustrates some terminology:
#
# <span><img src="attachment:DataFrame-terminology.png" alt="DataFrame terminology" align="center" width="400px"></span>
#
# * A **row** is a horizontal selection of data values.
# * A **column** is a vertical selection of data values.
# * The **index** provides an identification of the rows.
# * The **column labels** provide an identification of the columns.
#
# Typically, all values in one column have the same type.
# Values in a row can be of different types.

# %% [markdown]
# ### Information about a `DataFrame`
#
# The following attributes provide information about the `DataFrame df`.
#
# * **`df.shape`** : the number of rows and number of columns
# * **`df.index`** : the row index
# * **`df.columns`** : the column labels
# * **`df.dtype`** : the types of the values in each column

# %%
df_example.shape

# %%
df_example.index

# %%
df_example.columns

# %%
df_example.dtypes

# %% [markdown]
# The `DataFrame` function **`info()`** returns
# an overview of a data frame, including its `RangeIndex`, number of `non-null` elements per column, types of the values in each column, and memory usage:

# %%
df_example.info()

# %% [markdown]
# > NOTE: A class type, like the `DataFrame` type, defines a set of functions (also referred to as *methods*) that can be called on any variable of that type. These functions are called using the dot notation, e.g. `df.info()` calls the function `.info()` on the data frame `df`.
#
# We see that there are 4 rows. There are three columns of data, each containing 4 values of the following types:
#
# * column `'A'` contains 64-bit integers
# * column `'B'` contains generic Python objects
# > NOTE: A column containing `string` values, or values of different types, will  be assigned the `object` type.
# * column `'C'` contains boolean values

# %% [markdown]
# ### Exercise <span class="exercise">1.a</span>

# %% [markdown]
# Suppose we are given the names and years of birth of five persons,

# %%
names = ['Peter', 'Anna', 'Tom', 'John', 'Simone']
years = [ 1998, 2002, 1946, 1973, 1962 ]

# %% [markdown]
# and want to organize this information in a data frame.

# %% [markdown]
# Create a dataframe `df_years` out of this information containing two columns. One column should be labeled `'Name'` and contain the names, and the other should be labeled `'Year of birth'` and contain the year of birth.

# %%
#// BEGIN_TODO [EDA_1a] Create a dataframe (1 point)

df_years = pd.DataFrame({'Name': ['Peter', 'Anna', 'Tom', 'John', 'Simone'], 'Year of birth': [ 1998, 2002, 1946, 1973, 1962 ]})

#// END_TODO [EDA_1a]
df_years

# %% [markdown]
# ### Exercise <span class="exercise">1.b</span>

# %% [markdown]
# Use the `info()` function to get an overview of the dataframe `df_years`

# %%
#// BEGIN_TODO [EDA_1b] Get an overview of df_years (1 point)

df_years.info()

#// END_TODO [EDA_1b]

# %% [markdown]
# ##  <span class="section">2.</span> `Index` and `Series` objects
#
# To understand Pandas data frames better,
# you should know about two more data types:
#
# * **`pd.Index`**:
#     this is a special type of object that holds the index;
#     by default, it is just a range of integers starting from 0.
# * **`pd.Series`**:
#     this type represents a single named sequence of data values of the same type,
#     with an index.
#     It is used for a single column in a data frame,
#     but also for a row extracted from a data frame,
#     where the column labels then serve as the `Series` index,
#     and the row index serves as the `Series` name.
#
# Thus, a data frame is a sequence of `Series` objects,
# with a shared `Index` object.
# The names of the `Series` objects are the column labels.

# %% [markdown]
# Let us again consider the example with the list of names and years of birth

# %%
names = ['Peter', 'Anna', 'Tom', 'John', 'Simone']
years = [ 1998, 2002, 1946, 1973, 1962 ]

# %% [markdown]
# This time, instead of creating a data frame, we create a `Series` object out of the information as follows. The `Series` object itself will contain the years of birth, it will be indexed by the names, and the object will be called `'Years of birth'`. We assign the object to variable `se_years`:

# %%
se_years = pd.Series( years, index=names, name='Years of birth' )
se_years

# %% [markdown]
# ### Exercise <span class="exercise">2.a</span>

# %% [markdown]
# Create a `pd.Series` object containing the following prices (in Euro)

# %%
prices = [2, 1, 3, 2.5, 1.5 ]

# %% [markdown]
# and indexed by the following items

# %%
items  = ['bread', 'milk', 'chips', 'bananas', 'carrots']

# %% [markdown]
# The series should be named `'Price (Euro)'`. Assign the resulting series to the variable `se_shopping_list`.

# %%
#// BEGIN_TODO [EDA_2a] Create an indexed list (1 point)

se_shopping_list = pd.Series(prices, index = items, name = 'Price (Euro)')

#// END_TODO [EDA_2a]
se_shopping_list

# %% [markdown]
# ## Error handling
#
# In case of errors, it is often useful to inspect the variable types. We can inspect the type of `DataFrame` and `Series` variables using the **`type()`** function:

# %%
type(df_example) # type of the df variable

# %%
type(df_example['C']) # type of the 'C' column in the df DataFrame

# %%
type(se_years) # type of the se_years variable

# %% [markdown]
# Note that a column has the `Series` type, which is not the same as the type of the values inside of a column. You can get the type of the values inside of a column using **`df.dtypes`**:

# %%
df_example.dtypes['C']

# %% [markdown]
# ##  <span class="section">3.</span> Getting data from a `DataFrame`

# %% [markdown]
# You can **get a column** from a data frame by indexing, just like a sequence.
# The result is a `Series` object.
# This is useful to extract a particular feature from the data set.

# %%
df_example['B']

# %% [markdown]
# To **get a row** from a data frame,
# you use the `DataFrame` attribute `loc`.
# It is called an *indexer attribute*,
# because it supports indexing
# with *square brackets*, just like indexing of lists.
# The result is also a `Series` object:

# %%
df_example.loc[2]

# %% [markdown]
# You can **get a value** at a given location in a data frame
# in several ways:
#
# * **`df[column_label][row_index]`** : first get the column,
#     then get the value from the resulting `Series` object
# * **`df.loc[row_index, column_label]`** : get the value directly,
#     using `loc` with the row index and column label

# %%
df_example['B'][2]

# %%
df_example.loc[2, 'B']

# %% [markdown]
# _Slicing_ can be used to **get larger parts from a data frame**,
# with a syntax similar to the slicing of lists.
#
# > NOTE: When slicing `DataFrame` and `Series` objects
# > with the syntax `.loc[start:stop]`,
# > the **`stop` value is included**.
# > This contrasts to _list_ slicing, where `stop` is _not_ included.
#
# To select a slice of rows,
# use `.loc[start:stop]`.
# The result is a (new!) data frame:

# %%
df_example.loc[1:2]

# %% [markdown]
# When `start` or `stop` is omitted in the slice `start:stop`,
# the first or last item is implied. Therefore, `.loc[:]` extracts all rows:

# %%
df_example.loc[:]

# %% [markdown]
# The `DataFrame` function call **`df.head(n)`** returns the first `n` rows of the data frame `df_example`,
# regardless of how the rows are indexed.
# The default value for `n` is 5 (i.e. omitting the value in `df.head()` is equivalent to `df.head(5)`).

# %%
df_example.head(2)

# %% [markdown]
# You can also apply slicing to the columns:

# %%
df_example.loc[:, 'A':'B']

# %% [markdown]
# Note that here the first `:` argument tells to select all the rows.
#
# Using `.loc` we can also extract a particular slice of rows and columns in one go:

# %%
df_example.loc[1:2, 'A':'B']

# %% [markdown]
# To **get _non-adjacent_ rows**,
# use `.loc` with a _list of row indices_
# (note the **double square brackets**).
# The result is a (new!) data frame:

# %%
df_example.loc[[1, 3]]

# %% [markdown]
# You can also **get _non-adjacent_ columns**.
# One way is by providing a _list of column labels_ directly to the data frame
# (note the **double square brackets**).
# The result is a (new!) data frame:

# %%
df_example[['A', 'C']]

# %% [markdown]
# An alternative way of getting non-adjacent columns,
# is to use `.loc` with a _full slice_ for the rows using just '`:`':

# %%
df_example.loc[:, ['A', 'C']]

# %% [markdown]
# Note that `df_example['B']` returns column '`B`' as a `Series` object.
# Sometimes it is more convenient to get it as a `DataFrame` with one column.
# This is achieved by using a list with only one element `'B'` as column label
# (note the **double square brackets**):

# %%
df_example[['B']]

# %% [markdown]
# ### Exercise <span class="exercise">3.a</span>

# %% [markdown]
# For the purpose of this exercise, we first organize the information

# %%
prices = [2, 1, 3, 2.5, 1.5 ]
items  = ['bread', 'milk', 'chips', 'bananas', 'carrots']

# %% [markdown]
# into a data frame called `df_shopping_list`

# %%
df_shopping_list = pd.DataFrame( { 'Item': items, 'Price (Euro)': prices } )
df_shopping_list

# %% [markdown]
# Create a _new_ data frame containing the first four rows from `df_shopping_list` and assign it to `df_short_list`.

# %%
#// BEGIN_TODO [EDA_3a] Select first rows (1 point)

df_short_list = df_shopping_list.head(4)

#// END_TODO [EDA_3a]

df_short_list

# %% [markdown]
# ### Exercise <span class="exercise">3.b</span>
#
# Use an expression to select the `'Item'` column from the data frame `df_shopping_list` so that the result is a `Series` object.

# %%
#// BEGIN_TODO [EDA_3b] Select a column (1 point)

df_shopping_list['Item']

#// END_TODO [EDA_3b]

# %% [markdown]
# ### Exercise <span class="exercise">3.c</span>
#
# Use an expression to select the prices from the rows with indices 2 to 4 (including 4), but now make sure the result is a data frame.

# %%
#// BEGIN_TODO [EDA_3c] Select rows _and_ columns (1 point)

df_shopping_list.loc[2:4]

#// END_TODO [EDA_3c]

# %% [markdown]
# ## <span class="section" id="section_copy">4.</span> Modifying a `DataFrame`
#
# `DataFrame` objects are _mutable_.
# In this lesson we will only present two very basic ways of modifying a `DataFrame` object.

# %% [markdown]
# ### Changing a value in a `DataFrame`
#
# To change a value at a particular location of a data frame `df`,
# you can use an assignment to the selected item:
# ```python
# df.loc[row, column] = expression
# ```

# %%
df_example.loc[0, 'B'] = 'ACE'
df_example

# %% [markdown]
# ### Changing values in a slice from a `DataFrame`
#
# Modifying values in data frame slices is a little bit cumbersome.
#
# > **IMPORTANT:** For reasons outside the scope of this course, if you want to operate on slices, it is recommended to **explicitly create a copy** of the slice.
#
# For example, let us take a look at the `df` data frame again:

# %%
df_example

# %% [markdown]
# If we take a slice of the `df_example` data frame:

# %%
df_slice = df_example.loc[1:2].copy()
df_slice

# %% [markdown]
# and modify the values in the first row of the slice:

# %%
df_slice.loc[1, 'A'] = 8
df_slice.loc[1, 'B'] = "EIGHT"
df_slice

# %% [markdown]
# the original data frame will not be affected:

# %%
df_example

# %% [markdown]
# ### Exercise <span class="exercise">4.a</span>
#
# Let us continue with the shopping list example:

# %%
prices = [2, 1, 3, 2.5, 1.5 ]
items  = ['bread', 'milk', 'chips', 'bananas', 'carrots']
df_shopping_list = pd.DataFrame( { 'Item': items, 'Price (Euro)': prices } )
df_shopping_list

# %% [markdown]
# Change in the `df_shopping_list` data frame the price for the bananas to 2.00 Euro.

# %%
#// BEGIN_TODO [EDA_4a] Update banana price (1 point)

df_shopping_list.loc[3, 'Price (Euro)'] = 2.00

#// END_TODO [EDA_4a]
df_shopping_list

# %% [markdown]
# ### Exercise <span class="exercise">4.b</span>
#
# Create a shorter shopping list by taking the rows 0 to 2 from the `df_shopping_list` and assign it to `df_shorter_list`. Change in `df_shorter_list` the price of chips to 2.70 Euro, making sure that the original `df_shopping_list` is not affected.

# %%
#// BEGIN_TODO [EDA_4b] A new shorter list (1 point)

df_shorter_list = df_shopping_list.loc[0:2].copy()
df_shorter_list.loc[2,'Price (Euro)'] = 2.70

#// END_TODO [EDA_4b]

df_shorter_list

# %% [markdown]
# ## <span class="section">5.</span> Setting the index of a `DataFrame`
#
# It may be convenient sometimes to set the index of the data frame to one of the columns, to allow indexing by the values in that column when getting and modifying data.
#
# Recall the `df_example` data frame:

# %%
df_example

# %% [markdown]
# The function call **`df.set_index(col)`** returns a *new* data frame with the index in `df` set to column `col`. For example, let's get a copy of the data frame `df_example` with its index set to the column `'B'`:

# %%
df_index = df_example.set_index('B')
df_index

# %% [markdown]
# We can now select data from `df_index` using more descriptive names. For example, we can get the rows with index between `'two'` and `'four'`:

# %%
df_index.loc['two':'four']

# %% [markdown]
# Similarly, we can use the new index to modify a value at a particular location in a data frame:

# %%
df_index.loc['three', 'C'] = True
df_index

# %% [markdown]
# ### Exercise <span class="exercise">5.a</span>
#
# Set the index in the data frame `df_shopping_list` to the column `'Item'` and assign the new data frame to `df_shopping_list_index`.

# %%
#// BEGIN_TODO [EDA_5a] Set data frame index (1 point)

df_shopping_list_index = df_shopping_list.set_index('Item')

#// END_TODO [EDA_5a]

df_shopping_list_index

# %% [markdown]
# ### Exercise <span class="exercise">5.b</span>
# Set in the data frame `df_shopping_list_index` the price of milk to 1.50 Euro.

# %%
#// BEGIN_TODO [EDA_5b] Set value using new index (1 point)

df_shopping_list_index.loc['milk', 'Price (Euro)'] = 1.50

#// END_TODO [EDA_5b]

df_shopping_list_index

# %% [markdown]
# ##  <span class="section">6.</span> Reading data from a file into a `DataFrame`

# %% [markdown]
# In these lessons, we will mainly use the **comma-separated values** (**CSV**) format
# for storing simple data in a file.
#
# Our CSV files will (usually) have
#
# * one header line with column labels,
# * each row on a line of its own,
# * commas to separate the fields in each row
#     (in some cases, you may encounter semicolons or TABs),
# * strings enclosed in double quotes
#     (in some case, strings are not enclosed), and
# * floating-point numbers using a decimal point (not a comma).
#
# The example file is named `country.csv`, located in the `datasets` directory inside the directory containing this notebook:

# %%
file_countries = './datasets/country.csv'

# %% [markdown]
# > **Important:** If you move this notebook outside of the extracted zip archive, then you must make sure that the datasets are moved as well and accessible at the relative path above.

# %% [markdown]
# We use the function **`pd.read_csv`** to load the data from that file into a `DataFrame`
# that we will name `country_data`.

# %%
country_data = pd.read_csv(file_countries)
country_data.head()

# %% [markdown]
# ### Exercise <span class="exercise">6.a</span>
#
# Show just the `'name'`, `'area'` and `'population'` columns for the first 10 rows of `country_data`.

# %%
#// BEGIN_TODO [EDA_6a] Name, area, and population for first 10 rows (1 point)

country_data.loc[0:9, ['name', 'area', 'population']]

#// END_TODO [EDA_6a]

# %% [markdown]
# ### Exercise <span class="exercise">6.b</span>
#
# Get information on the data frame `country_data`, using one of the functions introduced earlier.

# %%
#// BEGIN_TODO [EDA_6b] Get information about country_data (1 point)

country_data.info()

#// END_TODO [EDA_6b]

# %% [markdown]
# We see that there are 251 rows.
# Therefore, some columns have missing values:
#
# * `tld` misses 2 values
# * `capital` misses 6 values
#
# These are the seven columns of data and their types:
#
# * `name` (string): country name in English
# * `alpha_3` (string): 3-letter ISO 3166-1 country code
# * `tld` (string): top-level domain in Domain Name System
# * `continent` (string): 2-letter continent code
# * `capital` (string): capital city in English
# * `area` (float): area in square kilometer
# * `population` (integer): population (measurement date/source unclear; cf. https://geonames.org/)

# %% [markdown]
# ##  <span class="section">7.</span> Summary statistics
#
# Summary statistics for **numeric columns** in a data frame `df`
# can be obtained by **`df.describe()`**:

# %%
country_data.describe()

# %% [markdown]
# To get summary statistics for **all columns** supply the argument **`include='all'`**:

# %%
country_data.describe(include='all')

# %% [markdown]
# > NOTE: **NaN** stands for **"Not a Number"** and represents a **missing value**,
# > also known as **not available** or **null value**.

# %% [markdown]
# From these summary statistics for the country data, we see that
#
# * names and alpha-3 codes are unique (maximum frequency equals 1)
# * 3 countries share the top-level domain `.gp`
# * there are 7 continents, and Africa has the most countries (58)
# * 2 capitals are named Kingston, and there are no other such duplicates

# %% [markdown]
# ### Separate statistics
#
# There are also functions to obtain separate statistics for `DataFrame df`:
#
# * **`df.count()`** : Return the **number** of values
# * **`df.sum()`** : Return the **sum** of the values
# * **`df.mean()`** : Return the **mean** of the values
# * **`df.std()`** : Return the **sample standard deviation** of the numeric values,
#     normalized by $N-1$, where $N$ is the number of values
# * **`df.min()`** : Return the **minimum** of the values
# * **`df.max()`** : Return the **maximum** of the values
# * **`df.median()`** : Return the **median** of the values
# * **`df.quantile(q)`** : Return the value at the given **quantile** `q`;
#     `q=0.5` is default, giving the **median**
#
# Notes:
#
# * **NaN/null values** are skipped by default.
# * A `Series` object is returned with the statistic for each column in the data frame.

# %% [markdown]
# Let's compute the total _area_ and *population*:

# %%
country_data[['area', 'population']].sum()

# %% [markdown]
# ### Exercise <span class="exercise">7.a</span>
#
# Count the number of values in the _capital_ column.

# %%
#// BEGIN_TODO [EDA_7a] Number of values in the 'capital' column (1 point)

country_data['capital'].count()

#// END_TODO [EDA_7a]

# %% [markdown]
# ### Exercise <span class="exercise">7.b</span>
#
# Compute the country population at the 0.42 quantile.

# %%
#// BEGIN_TODO [EDA_7b] 0.42 quantile in the 'population' column (1 point)

country_data['population'].quantile(0.42)

#// END_TODO [EDA_7b]

# %% [markdown]
# ## <span class="section">8.</span> Sorting a `DataFrame`
#
# To sort a data frame `df` by the values in column `'c'` use **`df.sort_values(by='c')`**.
# Note that this does not modify the data frame,
# but rather returns a new data frame.
# A series is sorted by the same function,
# but it does not need the `by` argument.
#
# Here is the country data sorted by *area*:

# %%
country_data.sort_values(by='area')

# %% [markdown]
# To sort in **descending order**, supply the argument **`ascending=False`**:

# %%
country_data.sort_values(by='area', ascending=False)

# %% [markdown]
# > A data frame can be **sorted in place**,
# > that is, the data frame is modified,
# > rather than returning a new data frame.
# > This is achieved by supplying the argument **`inplace=True`**,
# > but is not recommended (rather, assign the result to a new variable).

# %% [markdown]
# To **sort on multiple columns**, provide a *list of column labels*:

# %%
country_data.sort_values(by=['continent', 'name'])

# %% [markdown]
# As you can see, the index (left-most column) labels are sorted along as well.
# If you want to have a new index for the result, in sorted order,
# then you can use the function **`reset_index()`**.
# The old index is preserved as well in the column labeled `'index'`.
#
# Let's sort the country data by *population*,
# reset the index, and assign the result to variable `country_data_sorted_by_pop`:

# %%
country_data_sorted_by_pop = country_data.sort_values(by='population', ascending=False).reset_index()
country_data_sorted_by_pop

# %% [markdown]
# ### Exercise <span class="exercise">8.a</span>
#
# Sort the country data on _area_ in descending order, and show the _name_ and _area_ for the first 10 rows.

# %%
#// BEGIN_TODO [EDA_8a] Name and area of first 10 rows after sorting on area (1 point)

country_data.loc[0:9, ['name', 'area']].sort_values(by = 'area', ascending = False)

#// END_TODO [EDA_8a]

# %% [markdown]
# ## <span class="section">9.</span> Computing values from a `DataFrame`
#
# You can apply **arithmetic operations** on entire data frames or series,
# such as selected columns.
#
# Let's calculate the _population density_ (_population_ divided by *area*) for each country:

# %%
country_data['population'] / country_data['area']

# %% [markdown]
# ### Adding a new column to a `DataFrame`
#
# It is more useful to combine the computed population density with the existing data,
# by **adding a new column** with the computed density values.
# We put it in a new column labeled `'density'` as follows:

# %%
country_data['density'] = country_data['population'] / country_data['area']
country_data

# %% [markdown]
# ### Exercise <span class="exercise">9.a</span>
#
# Add a new column labeled `specific_area` with the _specific area_
# (_area_ divided by *population*) **expressed in $\mathrm{m}^2$ per person**,
# and show the first five rows of the data frame.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# The default value of `head()` is five.
# </span>

# %%
#// BEGIN_TODO [EDA_9a] Add 'specific_area' column (1 point)

country_data['specific_area'] = country_data['area'] * 1000000 / country_data['population']
country_data.head()

#// END_TODO [EDA_9a]

# %% [markdown]
# ## <span class="section">10.</span> Selecting rows by boolean masks
#
# A **boolean mask** is a list of boolean values that can be used to select those rows in a data frame for which the mask contains the value `True`. This is done by using the boolean mask as index of the data frame. The length of the mask must equal the number of rows in the data frame.
#
# For example, let's take a look at our shopping list example:

# %%
df_shopping_list

# %% [markdown]
# We can use a boolean mask of to select a subset of rows for which the mask has a `True` value:

# %%
df_shopping_list[[True, False, False, True, False]]

# %% [markdown]
# It is sometimes convenient to store a mask in a variable, e.g. to reuse it later:

# %%
mask = [True, False, False, True, False]
df_shopping_list[mask]

# %% [markdown]
# A boolean mask can be created by applying **comparison and logical operations** on selected columns. For example, let's compute a mask of products in our shopping list that cost less than 1.7 Euro:

# %%
df_shopping_list['Price (Euro)'] < 1.7

# %% [markdown]
# We can use the mask to select those products

# %%
df_shopping_list[df_shopping_list['Price (Euro)'] < 1.7]

# %% [markdown]
# As another example, let's compute which countries are in _Europe_ and assign the result to variable `countries_in_EU`:

# %%
countries_in_EU = country_data['continent'] == 'EU'
countries_in_EU

# %% [markdown]
# Let's use the mask `countries_in_EU` to select countries in *Europe*:

# %%
country_data[countries_in_EU]

# %% [markdown]
# Here is another example, selecting the data for the *Netherlands*, knowing that is has _top-level domain_ `.nl`:

# %%
country_data[country_data['tld'] == '.nl']

# %% [markdown]
# ### Boolean mask for missing values
#
# The `Series` function **`isnull()`** can be used to create a **boolean mask
# for missing values** (these are also known as **not available** (na) or **null values**).
#
# Which countries don't have a *top-level domain*:

# %%
country_data[country_data['tld'].isnull()]

# %% [markdown]
# ### Combining boolean masks
#
# Boolean masks can be combined into more complex boolean conditions using the following operators:
#
# * **`&`** for 'and'
# * **`|`** for 'or'
# * **`~`** for 'not'
#
# These operators apply the corresponding logical operator to each row in a data frame or series. For example, let's compute the truth table for the logical expression: not A or B:

# %%
df_truth = pd.DataFrame({'A': [True, True, False, False], 'B': [True, False, True, False]})
df_truth['A or B'] = df_truth['A'] | df_truth['B']
df_truth['not (A or B)'] = ~(df_truth['A'] | df_truth['B'])
df_truth

# %% [markdown]
# The operators for combining boolean masks bind stronger than comparison operators, e.g. `df['A'] & df['B'] < 42` is equivalent to `(df['A'] & df['B']) < 42`. Use parenthesis to evaluate comparisons first.
#
# For example, let's show data for countries with a _population_ less than one million and
# an _area_ more than one hundred thousand square kilometer:

# %%
country_data[(country_data['population'] < 1000000) & (country_data['area'] > 100000)]

# %% [markdown]
# ### Exercise <span class="exercise">10.a</span>
#
# Compute a boolean mask that is `True` for those rows that have `'Kingston'` as *capital*,
# and assign it to `capital_Kingston`.

# %%
#// BEGIN_TODO [EDA_10a] Boolean mask for capital Kingston (1 point)

capital_Kingston = country_data['capital'] == 'Kingston'

#// END_TODO [EDA_10a]

capital_Kingston

# %% [markdown]
# ### Exercise <span class="exercise">10.b</span>
#
# Show the data for countries with _capital_ `'Kingston'`,
# using the boolean mask `capital_Kingston` computed earlier:

# %%
#// BEGIN_TODO [EDA_10b] Show data for countries with capital Kingston (1 point)

country_data[capital_Kingston]

#// END_TODO [EDA_10b]

# %% [markdown]
# ### Exercise <span class="exercise">10.c</span>
#
# Compute a boolean mask that is `True` for those rows that have a _population_
# larger than 100 million.
# Assign it to the variable `large_population`.

# %%
#// BEGIN_TODO [EDA_10c] Boolean mask for population larger than 100 million (1 point)

large_population = country_data['population'] > 100000000

#// END_TODO [EDA_10c]

large_population

# %% [markdown]
# ### Exercise <span class="exercise">10.d</span>
#
# Show the data for countries whose _population_ exceeds 100 million,
# by using the boolean mask `large_population` computed earlier:

# %%
#// BEGIN_TODO [EDA_10d] Show data for countries with large population (1 point)

country_data[large_population]

#// END_TODO [EDA_10d]

# %% [markdown]
# ### Exercise <span class="exercise">10.e</span>
#
# Show the data for countries for which the _capital_ is missing in the data set.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# Use `isnull()` to construct an appropriate _boolean mask_.
# </span>

# %%
#// BEGIN_TODO [EDA_10e] Show data for countries whose capital is missing (1 point)

country_data[country_data['capital'].isnull()]

#// END_TODO [EDA_10e]

# %% [markdown]
# ### Exercise <span class="exercise">10.f</span>
#
# Show data for those countries in _Europe_ that have a _population_ between ten and twenty million.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# First compute three separate boolean masks: <code>countries_in_EU</code> for 'in Europe', <code>pop_more_10M</code> for 'population at least ten million', <code>pop_less_20M</code> for 'population at most twenty million'. Then combine them into one boolean mask using `&`.
# </span>

# %%
#// BEGIN_TODO [EDA_10f] Population between ten and twenty million (1 point)

countries_in_EU = country_data['continent'] == 'EU'
pop_more = country_data['population'] > 10000000
pop_less = country_data['population'] < 20000000
country_data[countries_in_EU & pop_more & pop_less]

#// END_TODO [EDA_10f]

# %% [markdown]
# ## <span class="section">11.</span> Grouping rows in a `DataFrame`

# %% [markdown]
# By sorting a data frame,
# you can bring items with the same value together.
# But this is not good enough to gather statistics
# about groups of equal values.
#
# Take for instance the country data.
# What about total _population_ and _area_ per *continent*?
#
# That is where **grouping** comes in.
# First, we create a so-called `GroupBy` object
# from the data frame,
# using the function **`groupby()`**
# with the column label(s) to group by as argument.
#
# This is how you group the country data by *continent*,
# and assign the `GroupBy` object to variable `grouped`.

# %%
grouped = country_data.groupby('continent')

# %% [markdown]
# The **`groups`** attribute of the `GroupBy` object
# shows for each continent which rows concern that continent:

# %%
grouped.groups

# %% [markdown]
# > Note that Australia and New Zealand are apparently put under Oceania,
# > since there is no separate continent `AU`.

# %% [markdown]
# The `GroupBy` object can be treated like a `DataFrame` in a number of ways.
#
# For instance, this is how you get the summary statistics for _area_ per _continent_:

# %%
grouped['area'].describe()

# %% [markdown]
# You can compute separate summary statistics for particular columns using one of several aggregation functions like **`.sum()`**, **`.mean()`**, **`.min()`**, or **`.median()`** (see the section on Summary statistics earlier for more aggregation functions). For example, this is how you get total _population_ and _area_ per *continent*:

# %%
grouped[['population', 'area']].sum()

# %% [markdown]
# You can also aggregate several quantities at once using **`.agg()`** and providing a dictionary as argument, containing the column names as keys and lists of quantities as values. For example, this is how to compute the mean and median population and the largest area:

# %%
grouped.agg({'population':['mean','median'], 'area':['max']})

# %% [markdown]
# ### Exercise <span class="exercise">11.a</span>
#
# Show the summary statistics for _population_ per _continent_ (you can reuse the variable `grouped` introduced before).

# %%
#// BEGIN_TODO [EDA_11a] Summary statistics for population per continent (1 point)

grouped['population'].describe()

#// END_TODO [EDA_11a]

# %% [markdown]
# ### Exercise <span class="exercise">11.b</span>
#
# Show the _maximum_ _density_ per _continent_ returning the result as a `Series` object:

# %%
#// BEGIN_TODO [EDA_11b] Maximum density per continent (1 point)

grouped['density'].max()

#// END_TODO [EDA_11b]

# %% [markdown]
# ### Exercise <span class="exercise">11.c</span>
#
# Show the minimum, maximum and total area per *continent*:

# %%
#// BEGIN_TODO [EDA_11c] Minimum, maximum and total area per continent (1 point)

grouped.agg({'area':['min','max','sum']})

#// END_TODO [EDA_11c]

# %% [markdown]
# ## <span class="section">12.</span> Deleting rows or columns from a `DataFrame`
#
# To delete one or more rows or columns from `DataFrame df`
# use the data frame function **`df.drop()`**.
#
# * **`df.drop(row)`**
# * **`df.drop(list_of_rows)`**
# * **`df.drop(column, axis=1)`**
# * **`df.drop(list_columns, axis=1)`**
#
# This returns a *new data frame*, with the specified rows or columns removed.
#
# The parameter `axis` indicates along which axis to drop, with `axis=0` referring to rows and `axis=1` referring to columns. The default is `axis=0`, to drop rows.
#
# For example, given the following data frame

# %%
df_example = pd.DataFrame({'A': [1, 2, 3, 4], 'B': ['one', 'two', 'three', 'four'], 'C': [False, True, False, True]})
df_example

# %% [markdown]
# You can drop the row with index label 1 (i.e. the second row):

# %%
df_example.drop(1)

# %% [markdown]
# You can drop the column with label 'C':

# %%
df_example.drop('C', axis=1)

# %% [markdown]
# You can also **drop rows based on a condition** using `drop()`,
# by cleverly combining
#
# * selection with a boolean mask and
# * the `index` attribute:
#
# ```python
# df.drop(df[boolean_mask].index)
# ```
#
# For example, you can drop countries in Europe from the `country_data` data frame:

# %%
country_data.drop(country_data[countries_in_EU].index)

# %% [markdown]
# ## <span class="section">13.</span> Persisting the modifications
#
# The data frame functions that we have discussed so far (`sort_values(), head(), drop()`) return a _new_ data frame, just like the `copy()` method we have seen before. To store the results of any modifications to a data frame we can assign the result to a new variable and then work on that variable.
#
# For example, the `drop()` function will return a new data frame:

# %%
df_drop = df_example.drop('C', axis=1)
df_drop

# %% [markdown]
# The original data frame `df_example` is not affected by the dropping:

# %%
df_example

# %% [markdown]
# Moreover, any modifications to `df_drop` will not affect `df`:

# %%
df_drop.loc[1, 'B'] = 'EIGHT'
df_drop

# %%
df_example

# %% [markdown]
# #### The `inplace` argument
#
# For many data frame methods you can supply the extra argument **`inplace=True`**, to store the modifications in the target data frame. However, this is usually not recommended; it is often better to assign the result to a new variable.

# %%
df_example.drop([1, 3], inplace=True)  # drop rows with index labels 1 and 3, modifying df in place
df_example

# %% [markdown]
# ## <span class="section">14.</span> Plotting a `DataFrame`

# %% [markdown]
# Various plots can be made directly from a `DataFrame` or `Series` object.
#
# First, we
#
# * import the underlying plotting libraries **Matplotlib** and **Seaborn**,
# * issue the command **`%matplotlib inline`**
#     to make plots appear inside the notebook,
# * and configure some parameters (see the comments for details).

# %%
# next command ensures that plots appear inside the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()  # set Seaborn defaults
plt.rcParams['figure.figsize'] = 10, 5  # default hor./vert. size of plots, in inches
plt.rcParams['lines.markeredgewidth'] = 1  # to fix issue with seaborn box plots; needed after import seaborn

# %% [markdown]
# > NOTE: This section presents a brief overview of plotting data for a quick exploration. More advanced plotting and annotation methods that are needed for communicating your data analysis with others will be addressed in _Exercises - VIS_.

# %% [markdown]
# The general function to make a plot for a `DataFrame df` is
#
# * **`df.plot(kind='...', ...)`**
#
# where the following kinds of plots are supported.
#
# * **`'line'`** : default
# * **`'area'`** : like `'line'`, but with area below line filled in
# * **`'bar'`** : vertical bar plot, with separated bars
# * **`'barh'`** : horizontal bar plot, with separated bars
# * **`'hist'`** : histogram, with automatic binning; use `bins=n` to set the number of bins to `n`
# * **`'box'`** : vertical box (and whisker) plot, with outliers
# * **`'density'`** : density plot (a kind of continuous histogram)
# * **`'scatter'`** : scatter plot
#
# All of these plots, **except `'scatter`'**, apply to `Series` objects as well.
#
# When used on a `DataFrame` object, all (numeric) columns are plotted, and a **legend** is included.
#
# The extra arguments are mostly irrelevant in this lesson; the ones that are relevant will be discussed below.
#
# Remember that you can get an explanation of all the function arguments like `kind='...'` with `?` or Shift-Tat-Tab. Execute the following cell to get built-in help for the Pandas plotting function (most of the details are irrelevant for this lesson):

# %%
country_data.plot?

# %% [markdown]
# You are encouraged to use the built-in help for the methods introduced below to explore and learn about other arguments they support.
#
# ### Line plot
#
# We begin with a **line plot** of the  _population_ per country. It shows the `'population'` column on the y-axis and the index (of the series `country_data['population']`) on the x-axis.
#
# Note that in this plot, since the x-axis has the row indices, the countries are ordered as in the original data file.

# %%
country_data['population'].plot();

# %% [markdown]
# The semicolon ('**`;`**') on the last line
# suppresses the textual output (which is not relevant for us).
#
# We can plot the _population_ in descending order,
# by using the earlier computed `country_data_sorted_by_pop`:

# %%
country_data_sorted_by_pop['population'].plot();

# %% [markdown]
# ### Area plot
#
# Now, the same plots as **area plot**:

# %%
country_data['population'].plot(kind='area');

# %%
country_data_sorted_by_pop['population'].plot(kind='area');

# %% [markdown]
# ### Dot plot
#
# A **dot plot** is obtained by creating a _line plot_ where the _marker_ is set to dots (**`marker='o'`**) and the lines are hidden (**`linestyle=''`**):

# %%
country_data['population'].plot(marker="o", linestyle='');

# %% [markdown]
# ### Histogram
#
# We plot a **histogram** for the _population_ in *Europe*,
# using the default number of bins.
# First, we select the relevant data,
# reusing the boolean mask `countries_in_EU`
# (this results in a `DataFrame` object,
# because of the double square brackets around `'population'`).

# %%
country_data[countries_in_EU][['population']].plot(kind='hist');

# %% [markdown]
# When plotting a single series of this data frame,
# the histogram will not include a legend
# (now there are single square brackets around `'population'`):

# %%
country_data[countries_in_EU]['population'].plot(kind='hist');

# %% [markdown]
# Next, we plot a **histogram** for this data,
# using 20 bins (`bins=20`), and normalizing the total area to one (`density=True`):

# %%
country_data[countries_in_EU][['population']].plot(kind='hist', bins=20, density=True);

# %% [markdown]
# ### Density plot
#
# A **density plot** (a kind of continuous histogram) for the same data:

# %%
country_data[countries_in_EU][['population']].plot(kind='density');

# %% [markdown]
# >NOTE: The contribution of each value is smeared out and integrated.
# > Of course, there are no negative populations.

# %% [markdown]
# ### Box plot
#
# A **box plot** for the _population_
# (note the **outliers**):

# %%
country_data[countries_in_EU][['population']].plot(kind='box');

# %% [markdown]
# For **box plots** of `DataFrame` objects, there is a special variant:
#
# * **`df.boxplot(column=..., by=...)`** :
#     side-by-side box plots for given column(s), grouped by given column(s)
#
# A **box plot** for the _population_ **grouped by** *continent*:

# %%
country_data.boxplot(column='population', by='continent');

# %% [markdown]
# > Note: if you receive a `FutureWarning` about `reshape` being deprecated, you can safely ignore it.

# %% [markdown]
# ### Bar plot
#
# A **bar plot** for the _number of countries_ per _continent_
# can be obtained via **grouping**.
# Recall that `grouped` was defined earlier
# to capture the grouping of country data per continent.

# %%
grouped['continent'].count().plot(kind='bar');

# %% [markdown]
# A **bar plot** for total _population_ per *continent*,
# again based on the grouping computed earlier:

# %%
grouped['population'].sum().plot(kind='bar');

# %% [markdown]
# ### Scatter plot
#
# A **scatter plot** that plots _area_ against _population_ using blue color:

# %%
country_data.plot(kind='scatter', x='area', y='population', c="b");

# %% [markdown]
# Note that the dot plot introduced earlier shows the index on the x-axis and one or more columns on the y-axis, while  the scatter plot is meant to visualize the relationship between two columns. You will learn more about both in *Exercises-VIS*.

# %% [markdown]
# ### Exercise <span class="exercise">14.a</span>
#
# Show a dot plot of _area_ per country.

# %%
#// BEGIN_TODO [EDA_14a] Dot plot for area per country (1 point)

country_data['area'].plot(marker = "o", linestyle = '');

#// END_TODO [EDA_14a]

# %% [markdown]
# ### Exercise <span class="exercise">14.b</span>
#
# Show an area plot of the _area_ per country sorted in descending order.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# First compute country data sorted in descending order by *area*,
# assigning it to `country_data_sorted_by_area`.
# Don't forget to use `.reset_index()`.
# </span>

# %%
#// BEGIN_TODO [EDA_14b] Area plot for area per country (1 point)

country_data_sorted_by_area = country_data.sort_values(by = 'area', ascending = False).reset_index()
country_data_sorted_by_area['area'].plot(kind = 'area');

#// END_TODO [EDA_14b]

# %% [markdown]
# ### Exercise <span class="exercise">14.c</span>
#
# Show a histogram with 30 bins for the country _area_ in _Europe_.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# Reuse the boolean mask `countries_in_EU` computed earlier.
# </span>

# %%
#// BEGIN_TODO [EDA_14c] Histogram for area per country in Europe (1 point)

countries_in_Europe = country_data[countries_in_EU]
countries_in_Europe['area'].plot(kind = 'hist', bins = 30);

#// END_TODO [EDA_14c]

# %% [markdown]
# The resulting histogram is not very informative,
# illustrating the limitation of histograms.
# Here, this is caused by one **outlier**.
#
# ### Exercise <span class="exercise">14.d</span>
#
# Define a boolean mask `countries_in_EU_not_RUS` for countries in _Europe_ without _Russia_.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# Reuse the boolean mask `countries_in_EU`. Keep in mind that the operators for combining boolean masks bind stronger than comparison operators. The `alpha_3` code of Russia is `RUS`.
# </span>

# %%
#// BEGIN_TODO [EDA_14d] Boolean mask for countries in Europe without Russia (1 point)

countries_in_EU_not_RUS = countries_in_EU & (~(country_data['alpha_3'] == 'RUS'))
countries_in_EU_not_RUS

#// END_TODO [EDA_14d]

# %% [markdown]
# ### Exercise <span class="exercise">14.e</span>
#
# Show a histogram with 30 bins for the country _area_ in _Europe_ without _Russia_.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# Reuse the boolean mask `countries_in_EU_not_RUS` computed earlier.
# </span>

# %%
#// BEGIN_TODO [EDA_14e] Histogram for area per country in Europe (1 point)

country_data[countries_in_EU_not_RUS]['area'].plot(kind = 'hist', bins = 30);

#// END_TODO [EDA_14e]

# %% [markdown]
# ### Exercise <span class="exercise">14.f</span>
#
# Show a density plot for the country _area_ in _Europe_ without _Russia_.

# %%
#// BEGIN_TODO [EDA_14f] Density plot for area per country in Europe (1 point)

country_data[countries_in_EU_not_RUS]['area'].plot(kind = 'density');

#// END_TODO [EDA_14f]

# %% [markdown]
# ### Exercise <span class="exercise">14.g</span>
#
# Show a box plot for the country _area_ in _Europe_ without *Russia*:

# %%
#// BEGIN_TODO [EDA_14g] Box plot for area per country in Europe without Russia (1 point)

country_data[countries_in_EU_not_RUS]['area'].plot(kind = 'box');

#// END_TODO [EDA_14g]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f1f1dfb44b95> in <module>
#       1 #// BEGIN_TODO [EDA_14g] Box plot for area per country in Europe without Russia (1 point)
#       2
# ----> 3 country_data[countries_in_EU_not_RUS]['area'].plot(kind = 'box');
#       4
#       5 #// END_TODO [EDA_14g]
#
# NameError: name 'country_data' is not defined

# %% [markdown]
# ### Exercise <span class="exercise">14.h</span>
#
# A box plot for country _area_ grouped by *continent*:

# %%
#// BEGIN_TODO [EDA_14h] Box plots for country area grouped by continent (1 point)

country_data.boxplot(column='area', by='continent') ;

#// END_TODO [EDA_14h]

# %% [markdown]
# ### Exercise <span class="exercise">14.i</span>
#
# Show a scatter plot that plots _area_ against _population_
# for countries in _Europe_ without *Russia*:

# %%
#// BEGIN_TODO [EDA_14i] Scatter plot for area against population for countries in Europe without Russia (1 point)

country_data[countries_in_EU_not_RUS].plot(kind = 'scatter', x = 'area', y = 'population', c = "b");

#// END_TODO [EDA_14i]

# %% [markdown]
# # <span class="section">15.</span> Exercise: speed of light
#
# Now let's put your data exploration skills to the test by evaluating an old experiment measuring the speed of light.
#
#
# *In the earlier exercises you were closely guided. In the following exercises we will put your knowledge to the test.*
#
# *Note that these exercises may seem more difficult as you will need to work more indepedently. When you struggle with an exercise then go back to the corresponding earlier section and make sure you really understand the introduced concepts. Do not hesitate to experiment with your own code!*
#
#
# In the 19th century, French physicists Fizeau and Foucault independently invented ways to measure the speed of light. Foucault's method turned out to be the most accurate one. The American physicists Michelson and Newcomb improved Foucault's method. The data set `light.csv` contains measurements by Newcomb from 1882.

# %% [markdown]
# ### Exercise <span class="exercise">15.a</span>: Load the data set
#
# Write Python code to load the data set into a Pandas `DataFrame` named `df_light` and show the first 10 rows.

# %%
file_light = './datasets/light.csv'

#// BEGIN_TODO [EDA_15a] Load the data set and show first 10 rows (1 point)

df_light = pd.read_csv(file_light)
df_light.head(10)

#// END_TODO [EDA_15a]

# %% [markdown]
# ### Exercise <span class="exercise">15.b</span>: Summary statistics of raw values
#
# Show the summary statistics for the `df_light` data frame.

# %%
#// BEGIN_TODO [EDA_15b] Summary statistics (1 point)

df_light.describe(include = 'all')

#// END_TODO [EDA_15b]

# %% [markdown]
# ### Exercise <span class="exercise">15.c</span>: Observation
#
# Looking at the summary statistics, what do you observe? Select one of the answers below and assign your answer as string to the variable `stats_observation`, e.g. `stats_observation = 'a'`.
#
# a) The mean and the median are equal.
#
# b) It is not clear how these values are related to the speed of light.
#
# c) On average, the values are as expected.
#
# d) The median is in the middle between the min and max and equal to -2.

# %%
#// BEGIN_TODO [EDA_15c] What do you notice? (1 point)

stats_observation = 'b'

#// END_TODO [EDA_15c]

stats_observation

# %% [markdown]
# ### Exercise <span class="exercise">15.d</span>: Add column with the decoded speed
#
# It turns out that Newcomb encoded his measurements to get smaller numbers to save space in his table. The coding of these measurements was as follows:
#
# > From the original measurements of time (**in microseconds**) needed by light to travel a distance of 7442 meters,
# > first 24.8 was subtracted,
# > after which the results were multiplied with 1000.
#
# Create a new column labeled `"Speed [km/s]"` in your data set with the measured light speed in km/s.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# Write down on a piece of paper the formula that Newcomb used to encode his measurements. This will help you to reverse the computation.
# </span>

# %%
#// BEGIN_TODO [EDA_15d] Added column with speed in km/s (3 points)

df_light["Speed [km/s]"] = (7442 / 1000) / (((df_light['Measurement'] / 1000) + 24.8) * 10 ** -6)
df_light

#// END_TODO [EDA_15d]

# %% [markdown]
# ### Exercise <span class="exercise">15.e</span>: Summary statistics of the decoded speed
#
# Show the summary statistics for the speed of light in km/s.

# %%
#// BEGIN_TODO [EDA_15e] Summary statics of speed (1 point)

df_light['Speed [km/s]'].describe()

#// END_TODO [EDA_15e]

# %% [markdown]
# ### Exercise <span class="exercise">15.f</span>: Make a dot plot
#
# Make a dot plot of the speed of light in km/s against the observation number (the observations are ordered by time).

# %%
#// BEGIN_TODO [EDA_15f] Plot data against observation number (1 point)

df_light['Speed [km/s]'].plot(marker = 'o', linestyle = ' ');

#// END_TODO [EDA_15f]

# %% [markdown]
# ### Exercise <span class="exercise">15.g</span>: Remove suspicious rows
#
# Clean the data by removing any suspicious observations that you found by visually inspecting the plot in the previous question. Store the modified `DataFrame` under the name `df_light_clean`, and recompute the summary statistics of the speed of light in km/s in `df_light_clean`.
#
# <span class="t">Hint<span class="c">:</span></span>
# <span class="h">
# You are encouraged to add new markdown and code cells between the marker lines to explain the steps you are taking, e.g. what you define as a suspicious observation. You can simply drop a list of indexes of rows containing the suspicious observations.
# </span>

# %%
#// BEGIN_TODO [EDA_15g] Remove suspicious rows (3 points)

df_light_clean = df_light.drop([5, 9])

# %%
#// END_TODO [EDA_15g]

# %% [markdown]
# ### Exercise <span class="exercise">15.h</span>: Find the definition of the speed of light
#
# Since the time when Newcomb did his experiments, the speed of light has been precisely defined. Find (using external sources) the definition of the speed of light in km/s. Assign this value (in km/s) to the variable `c`.

# %%
#// BEGIN_TODO [EDA_15h] Current estimate of the speed of light (1 point)

c = 299792.458

#// END_TODO [EDA_15h]

c

# %% [markdown]
# ### Exercise <span class="exercise">15.i</span>: Compare to current estimate
#
# Is the value of `c` in the previous exercise consistent with Newcomb's measurements in the _cleaned_ data?
#
# Compute the **relative error percentage** of Newcomb's mean value in `df_light_clean` with respect to the current estimate `c`, i.e.
#
# $$
# \textsf{relative error percentage} = \frac{(\textsf{Newcomb's mean value}) - (\textsf{current estimate})}{\textsf{current estimate}} \times 100
# $$
#
# Assign your computed relative error percentage to the variable `newcomb_rel`.

# %%
#// BEGIN_TODO [EDA_15i] Compare to current measurements (2 points)

newcomb_rel = (299745.257105 - c)/c * 100

# %%
#// END_TODO [EDA_15i]

newcomb_rel

# %% [markdown]
# # Feedback
#
# Please fill in this questionaire to help us improve this course for the next year. Your feedback will be anonymized and will not affect your grade in any way!

# %% [markdown]
# ### How many hours did you spend on these Exercises?
#
# Assign a number to `feedback_time`.

# %%
#// BEGIN_FEEDBACK [Feedback_1] (0 point)

feedback_time = 3

#// END_FEEDBACK [Feedback_1] (0 point)

import numbers
assert isinstance(feedback_time, numbers.Number), "Please assign a number to feedback_time"
feedback_time

# %% [markdown]
# ### How difficult did you find these Exercises?
#
# Assign an integer to `feedback_difficulty`, on a scale 0 - 10, with 0 being very easy, 5 being just right, and 10 being very difficult.

# %%
#// BEGIN_FEEDBACK [Feedback_2] (0 point)

feedback_difficulty = 5

#// END_FEEDBACK [Feedback_2] (0 point)

import numbers
assert isinstance(feedback_difficulty, numbers.Number), "Please assign a number to feedback_difficulty"
feedback_difficulty

# %% [markdown]
# ### (Optional) What did you like?
#
# Assign a string to `feedback_like`.

# %%
#// BEGIN_FEEDBACK [Feedback_3] (0 point)

#// END_FEEDBACK [Feedback_3] (0 point)

# %% [markdown]
# ### (Optional) What can be improved?
#
# Assign a string to `feedback_improve`. Please be specific, so that we can act on your feedback. For example, mention the specific exercises and what was unclear.

# %%
#// BEGIN_FEEDBACK [Feedback_4] (0 point)

#// END_FEEDBACK [Feedback_4] (0 point)

# %% [markdown]
# ## How to submit your work
#
# 1. **Before submitting**, you must run your notebook by doing **Kernel > Restart & Run All**.
#    Make sure that your notebook runs without errors **in linear order**.
#
# 2. Remember to rename the notebook, replacing `...-template.ipynb` with `...-yourIDnr.ipynb`, where `yourIDnr` is your TU/e identification number.
#
# 3. Submit the executed notebook with your work
#    for the appropriate assignment in **Canvas**.
#
# * In the **Momotor** tab in Canvas,
#   you can select that assignment again to find some feedback on your submitted work.
#
# * If there are any problems reported by _Momotor_,
#   then you need to fix those,
#   and **resubmit the fixed notebook**.
#
# In case of a high workload on our server
# (because many students submit close to the deadline),
# it may take longer to receive the feedback.

# %% [markdown]
# ---

# %%
# List all defined names
# %whos

# %% [markdown]
# ---
#
# # (End of Notebook) <span class="tocSkip"></span>
#
# &copy; 2017-2021 - **TU/e** - Eindhoven University of Technology
